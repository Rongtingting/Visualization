# %% [markdown]
# ## 01-display plotted image

# %%
# import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10,12))
img = plt.imread('/storage/yhhuang/users/julialam/CaSpER/gx109/heatmap.png')
# image = plt.imread('1.jpg')
plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt

# imgs= get_gray_imgs()

fig, axes = plt.subplots(2, 5)
fig.set_size_inches(30, 7)
# fig.subplots_adjust(left=0.04, top= 0.96, right = 0.96, bottom = 0.04, wspace = 0.01, hspace = 0.01)   
fig.set_tight_layout(True)  # subplots_adjust 约束太多，不容易计算，效果不好
axes = axes.flatten()
for i in range(10):
    axes[i].imshow(img, cmap="gray")
    axes[i].set_title("img " + str(i), fontsize=52)
    axes[i].set_axis_off()
fig.show()
# fig.savefig('imgs.png', dpi=600, format='png')

# %%
## 02-
